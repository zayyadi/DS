# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datasets/african_crises.csv')

# %%
df
# Out:
#       case  cc3   country  year  systemic_crisis    exch_usd  \
# 0        1  DZA   Algeria  1870                1    0.052264
# 1        1  DZA   Algeria  1871                0    0.052798
# 2        1  DZA   Algeria  1872                0    0.052274
# 3        1  DZA   Algeria  1873                0    0.051680
# 4        1  DZA   Algeria  1874                0    0.051308
# ...    ...  ...       ...   ...              ...         ...
# 1054    70  ZWE  Zimbabwe  2009                1  354.800000
# 1055    70  ZWE  Zimbabwe  2010                0  378.200000
# 1056    70  ZWE  Zimbabwe  2011                0  361.900000
# 1057    70  ZWE  Zimbabwe  2012                0  361.900000
# 1058    70  ZWE  Zimbabwe  2013                0  361.900000
#
#       domestic_debt_in_default  sovereign_external_debt_default  \
# 0                            0                                0
# 1                            0                                0
# ...

# %%
df1 = df[df.country=='Nigeria']

df1.head()
# Out:
#      case  cc3  country  year  systemic_crisis  exch_usd  \
# 648    45  NGA  Nigeria  1954                0       0.0
# 649    45  NGA  Nigeria  1955                0       0.0
# 650    45  NGA  Nigeria  1956                0       0.0
# 651    45  NGA  Nigeria  1957                0       0.0
# 652    45  NGA  Nigeria  1958                0       0.0
#
#      domestic_debt_in_default  sovereign_external_debt_default  \
# 648                         0                                0
# 649                         0                                0
# 650                         0                                0
# 651                         0                                0
# 652                         0                                0
#
#      gdp_weighted_default  inflation_annual_cpi  independence  \
# 648                   0.0              3.102916             0
# 649                   0.0              6.173562             0
# ...

# %%
CEY = df[['country', 'exch_usd', 'year', 'inflation_annual_cpi']]
CEY.head()
NG = CEY.loc[CEY['country'] =='Nigeria']
NG90 = NG.tail(16)
NG90
# Out:
#      country  exch_usd  year  inflation_annual_cpi
# 692  Nigeria   97.9500  1999                 6.618
# 693  Nigeria  109.5500  2000                 6.938
# 694  Nigeria  112.9500  2001                18.869
# 695  Nigeria  126.4000  2002                12.883
# 696  Nigeria  136.5000  2003                14.033
# 697  Nigeria  132.3500  2004                15.001
# 698  Nigeria  129.0000  2005                17.856
# 699  Nigeria  128.2700  2006                 8.218
# 700  Nigeria  117.9680  2007                 5.413
# 701  Nigeria  132.5625  2008                11.581
# 702  Nigeria  149.5810  2009                12.543
# 703  Nigeria  150.6617  2010                13.720
# 704  Nigeria  158.2670  2011                10.841
# 705  Nigeria  155.2700  2012                12.225
# 706  Nigeria  155.2000  2013                 8.495
# 707  Nigeria  155.2500  2014                 8.048

# %%
color_list = ['red','black']
ax = NG90.plot('year','exch_usd', kind='bar',figsize=(20,8),width=0.8,color = color_list,edgecolor = None)
plt.title("exchange rate flow from 1999 to 2014", fontsize=16)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df1.groupby(['year']).sum()
# Out:
#       case  systemic_crisis    exch_usd  domestic_debt_in_default  \
# year
# 1954    45                0    0.000000                         0
# 1955    45                0    0.000000                         0
# 1956    45                0    0.000000                         0
# 1957    45                0    0.000000                         0
# 1958    45                0    0.000000                         0
# 1959    45                0    0.000000                         0
# 1960    45                0    0.000000                         0
# 1961    45                0    0.000000                         0
# 1962    45                0    0.000000                         0
# 1963    45                0    0.000000                         0
# 1964    45                0    0.000000                         0
# 1965    45                0    0.000000                         0
# 1966    45                0    0.000000                         0
# ...

# %%
#Let's have a look at currency rate
sns.set_style('whitegrid')
plt.figure(figsize = (8,5))
sns.lineplot(x = 'year', y = 'inflation_annual_cpi', hue = 'independence', data =df1,palette = 'colorblind')
plt.xlabel('Year')
plt.ylabel('Exchange Rate')
display()

# %%
df1[df['year']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-c13ea353d205> in <module>
# ----> 1 df1[df['year']].unique()
#
# C:\Python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# C:\Python37\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
# ...

# %%
sns.set_style('whitegrid')
fig, axes = plt.subplots(ncols=4, nrows=4, figsize=(18,12), dpi= 60)
axes = axes.flatten()
for i, ax in zip(df['country'].unique(), axes):
  sns.lineplot(x = 'year', y = 'exch_usd', hue = 'independence', data = df[df['country'] == i], ax = ax)
  ax.set_xlabel('Year')
  ax.set_ylabel('Exchange Rate')
  ax.set_title('{}'.format(i))
  ax.get_legend().remove()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc=1)
fig.subplots_adjust(top=0.95)
for i in range(13,16):
  fig.delaxes(axes[i])
plt.tight_layout()

# %%
fig, axes = plt.subplots(ncols=4, nrows=4, figsize=(18,12), dpi= 60)
axes = axes.flatten()
for i, ax in zip(df['country'].unique(), axes):
  sns.lineplot(x = 'year', y = 'inflation_annual_cpi', data = df[df['country'] == i], ax = ax, color = 'cornflowerblue')
  ax.set_xlabel('Year')
  ax.set_ylabel('Inflation Rate')
  ax.set_title('{}'.format(i))
  inflation = df[(df['country'] == i) & (df['inflation_crises'] == 1)]['year'].unique()
  for i in inflation:
    ax.axvline(x=i, color='indianred', linestyle='--', linewidth=.9)
fig.subplots_adjust(top=0.95)
for i in range(13,16):
  fig.delaxes(axes[i])
plt.tight_layout()

# %%
fig, axes = plt.subplots(ncols=4, nrows=4, figsize=(18,12), dpi= 60)
axes = axes.flatten()
def hyperinflation ():
    for i in zip (df1[df1['year']], axes)
        sns.lineplot(x = 'year', y = 'inflation_annual_cpi', data = df[df['country'] == i], ax = ax, color = 'cornflowerblue')
        ax.set_xlabel('Year')
        ax.set_ylabel('Inflation Rate')
        ax.set_title('{}'.format(i))
  inflation = df[(df['country'] == i) & (df['inflation_crises'] == 1)]['year'].unique()
  for i in inflation:
    ax.axvline(x=i, color='indianred', linestyle='--', linewidth=.9)
fig.subplots_adjust(top=0.95)
for i in range(13,16):
  fig.delaxes(axes[i])
plt.tight_layout()
